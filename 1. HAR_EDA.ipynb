# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Link :
# >https://archive.ics.uci.edu/ml/machine-learning-databases/00240/
# - Extract the zip file to obtain the folder UCI HAR Dataset, rename the folder to UCI_HAR_dataset.

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
# pd.read_csv() - "names" is a LIST which serves as header for the columns
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# C:\Users\LENOVO-PC\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 7031           0.269661           -0.01853          -0.107585
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 7031         -0.983395         -0.988092         -0.981767         -0.988162
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 7031         -0.989536         -0.984313          -0.93079      ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 7031                     0.154557                             -0.409579
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 7031                         -0.070852                               0.54067
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 7031              0.513343             -0.391982             -0.614962
#
#       subject  Activity  ActivityName
# 7031       30         6        LAYING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
# C:\Users\LENOVO-PC\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2315           0.287286          -0.016265          -0.110868
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2315         -0.988733         -0.991823         -0.996517         -0.989031
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 2315          -0.99044         -0.996486         -0.933077      ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2315                     0.071476                             -0.041102
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2315                          0.429408                             -0.397934
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2315              0.654658             -0.579794             -0.421297
#
#       subject  Activity  ActivityName
# 2315       20         6        LAYING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# __We have got almost same number of reading from all the subjects__

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %% [markdown]
# __Observation__ : We see that staitionary and moving activities are distiguishable. So lets zoom in more

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can separate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleXgravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data for 2D visualization

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.391s...
# [t-SNE] Computed neighbors for 7352 samples in 40.625s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.087s
# [t-SNE] Iteration 50: error = 124.6637878, gradient norm = 0.0260516 (50 iterations in 9.523s)
# [t-SNE] Iteration 100: error = 107.0083771, gradient norm = 0.0286025 (50 iterations in 6.477s)
# [t-SNE] Iteration 150: error = 100.7410965, gradient norm = 0.0205642 (50 iterations in 5.318s)
# [t-SNE] Iteration 200: error = 97.3818817, gradient norm = 0.0169460 (50 iterations in 4.796s)
# [t-SNE] Iteration 250: error = 95.0834045, gradient norm = 0.0121706 (50 iterations in 4.692s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.083405
# [t-SNE] Iteration 300: error = 4.1152015, gradient norm = 0.0015593 (50 iterations in 4.674s)
# [t-SNE] Iteration 350: error = 3.2076018, gradient norm = 0.0010064 (50 iterations in 5.029s)
# [t-SNE] Iteration 400: error = 2.7801332, gradient norm = 0.0007096 (50 iterations in 5.327s)
# [t-SNE] Iteration 450: error = 2.5163879, gradient norm = 0.0005669 (50 iterations in 4.973s)
# [t-SNE] Iteration 500: error = 2.3332677, gradient norm = 0.0004817 (50 iterations in 5.033s)
# [t-SNE] Iteration 550: error = 2.1952195, gradient norm = 0.0004172 (50 iterations in 5.033s)
# [t-SNE] Iteration 600: error = 2.0859606, gradient norm = 0.0003718 (50 iterations in 5.055s)
# [t-SNE] Iteration 650: error = 1.9963702, gradient norm = 0.0003322 (50 iterations in 5.202s)
# [t-SNE] Iteration 700: error = 1.9208864, gradient norm = 0.0003022 (50 iterations in 5.371s)
# [t-SNE] Iteration 750: error = 1.8560836, gradient norm = 0.0002790 (50 iterations in 5.367s)
# [t-SNE] Iteration 800: error = 1.7994795, gradient norm = 0.0002528 (50 iterations in 5.176s)
# [t-SNE] Iteration 850: error = 1.7495748, gradient norm = 0.0002408 (50 iterations in 4.931s)
# [t-SNE] Iteration 900: error = 1.7052013, gradient norm = 0.0002252 (50 iterations in 5.168s)
# [t-SNE] Iteration 950: error = 1.6652778, gradient norm = 0.0002081 (50 iterations in 5.338s)
# [t-SNE] Iteration 1000: error = 1.6289417, gradient norm = 0.0001994 (50 iterations in 5.164s)
# [t-SNE] Error after 1000 iterations: 1.628942
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.238s...
# [t-SNE] Computed neighbors for 7352 samples in 39.367s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.060s
# [t-SNE] Iteration 50: error = 113.8606491, gradient norm = 0.0250540 (50 iterations in 9.108s)
# [t-SNE] Iteration 100: error = 97.3199692, gradient norm = 0.0191430 (50 iterations in 6.223s)
# [t-SNE] Iteration 150: error = 93.0203247, gradient norm = 0.0094561 (50 iterations in 5.249s)
# [t-SNE] Iteration 200: error = 91.0682220, gradient norm = 0.0062120 (50 iterations in 5.076s)
# [t-SNE] Iteration 250: error = 89.9078293, gradient norm = 0.0046193 (50 iterations in 5.000s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.907829
# [t-SNE] Iteration 300: error = 3.5716865, gradient norm = 0.0014608 (50 iterations in 5.074s)
# [t-SNE] Iteration 350: error = 2.8137176, gradient norm = 0.0007539 (50 iterations in 5.103s)
# [t-SNE] Iteration 400: error = 2.4328933, gradient norm = 0.0005213 (50 iterations in 5.204s)
# [t-SNE] Iteration 450: error = 2.2150946, gradient norm = 0.0004040 (50 iterations in 5.181s)
# [t-SNE] Iteration 500: error = 2.0702093, gradient norm = 0.0003325 (50 iterations in 5.167s)
# [t-SNE] Iteration 550: error = 1.9649482, gradient norm = 0.0002800 (50 iterations in 5.292s)
# [t-SNE] Iteration 600: error = 1.8836089, gradient norm = 0.0002465 (50 iterations in 5.235s)
# [t-SNE] Iteration 650: error = 1.8182530, gradient norm = 0.0002195 (50 iterations in 5.362s)
# [t-SNE] Iteration 700: error = 1.7644655, gradient norm = 0.0001984 (50 iterations in 5.330s)
# [t-SNE] Iteration 750: error = 1.7191095, gradient norm = 0.0001797 (50 iterations in 5.321s)
# [t-SNE] Iteration 800: error = 1.6800615, gradient norm = 0.0001659 (50 iterations in 5.306s)
# [t-SNE] Iteration 850: error = 1.6461700, gradient norm = 0.0001533 (50 iterations in 5.332s)
# [t-SNE] Iteration 900: error = 1.6163211, gradient norm = 0.0001427 (50 iterations in 5.209s)
# [t-SNE] Iteration 950: error = 1.5901312, gradient norm = 0.0001333 (50 iterations in 5.210s)
# [t-SNE] Iteration 1000: error = 1.5664576, gradient norm = 0.0001250 (50 iterations in 5.438s)
# [t-SNE] Error after 1000 iterations: 1.566458
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.234s...
# [t-SNE] Computed neighbors for 7352 samples in 45.010s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.107s
# [t-SNE] Iteration 50: error = 105.9163055, gradient norm = 0.0174438 (50 iterations in 9.859s)
# [t-SNE] Iteration 100: error = 90.4405441, gradient norm = 0.0093697 (50 iterations in 7.224s)
# [t-SNE] Iteration 150: error = 87.3622589, gradient norm = 0.0053703 (50 iterations in 6.739s)
# [t-SNE] Iteration 200: error = 86.1109161, gradient norm = 0.0038436 (50 iterations in 7.834s)
# [t-SNE] Iteration 250: error = 85.3955765, gradient norm = 0.0029356 (50 iterations in 7.024s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.395576
# [t-SNE] Iteration 300: error = 3.1335101, gradient norm = 0.0013940 (50 iterations in 6.933s)
# [t-SNE] Iteration 350: error = 2.4913409, gradient norm = 0.0006492 (50 iterations in 6.293s)
# [t-SNE] Iteration 400: error = 2.1713440, gradient norm = 0.0004286 (50 iterations in 6.247s)
# [t-SNE] Iteration 450: error = 1.9869442, gradient norm = 0.0003141 (50 iterations in 6.355s)
# [t-SNE] Iteration 500: error = 1.8684002, gradient norm = 0.0002540 (50 iterations in 6.595s)
# [t-SNE] Iteration 550: error = 1.7850906, gradient norm = 0.0002121 (50 iterations in 6.597s)
# [t-SNE] Iteration 600: error = 1.7225339, gradient norm = 0.0001808 (50 iterations in 6.608s)
# [t-SNE] Iteration 650: error = 1.6736341, gradient norm = 0.0001611 (50 iterations in 6.756s)
# [t-SNE] Iteration 700: error = 1.6340572, gradient norm = 0.0001430 (50 iterations in 6.638s)
# [t-SNE] Iteration 750: error = 1.6010746, gradient norm = 0.0001300 (50 iterations in 6.237s)
# [t-SNE] Iteration 800: error = 1.5737052, gradient norm = 0.0001185 (50 iterations in 6.236s)
# [t-SNE] Iteration 850: error = 1.5503109, gradient norm = 0.0001089 (50 iterations in 6.470s)
# [t-SNE] Iteration 900: error = 1.5296201, gradient norm = 0.0001035 (50 iterations in 6.494s)
# [t-SNE] Iteration 950: error = 1.5116148, gradient norm = 0.0000959 (50 iterations in 6.841s)
# [t-SNE] Iteration 1000: error = 1.4958931, gradient norm = 0.0000917 (50 iterations in 6.766s)
# [t-SNE] Error after 1000 iterations: 1.495893
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.243s...
# [t-SNE] Computed neighbors for 7352 samples in 41.126s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.236s
# [t-SNE] Iteration 50: error = 97.5181274, gradient norm = 0.0183286 (50 iterations in 12.432s)
# [t-SNE] Iteration 100: error = 84.7510452, gradient norm = 0.0065630 (50 iterations in 8.039s)
# [t-SNE] Iteration 150: error = 82.3204727, gradient norm = 0.0047791 (50 iterations in 7.833s)
# [t-SNE] Iteration 200: error = 81.3869019, gradient norm = 0.0029844 (50 iterations in 7.974s)
# [t-SNE] Iteration 250: error = 80.9223785, gradient norm = 0.0025608 (50 iterations in 7.713s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.922379
# [t-SNE] Iteration 300: error = 2.7102158, gradient norm = 0.0013136 (50 iterations in 8.111s)
# [t-SNE] Iteration 350: error = 2.1737623, gradient norm = 0.0005844 (50 iterations in 7.620s)
# [t-SNE] Iteration 400: error = 1.9222038, gradient norm = 0.0003501 (50 iterations in 7.537s)
# [t-SNE] Iteration 450: error = 1.7745939, gradient norm = 0.0002499 (50 iterations in 7.426s)
# [t-SNE] Iteration 500: error = 1.6799678, gradient norm = 0.0001954 (50 iterations in 7.528s)
# [t-SNE] Iteration 550: error = 1.6148558, gradient norm = 0.0001606 (50 iterations in 7.526s)
# [t-SNE] Iteration 600: error = 1.5678412, gradient norm = 0.0001348 (50 iterations in 7.528s)
# [t-SNE] Iteration 650: error = 1.5323887, gradient norm = 0.0001191 (50 iterations in 7.534s)
# [t-SNE] Iteration 700: error = 1.5050290, gradient norm = 0.0001073 (50 iterations in 7.831s)
# [t-SNE] Iteration 750: error = 1.4830009, gradient norm = 0.0000972 (50 iterations in 7.538s)
# [t-SNE] Iteration 800: error = 1.4651804, gradient norm = 0.0000900 (50 iterations in 7.523s)
# [t-SNE] Iteration 850: error = 1.4507049, gradient norm = 0.0000837 (50 iterations in 7.524s)
# [t-SNE] Iteration 900: error = 1.4386055, gradient norm = 0.0000796 (50 iterations in 7.766s)
# [t-SNE] Iteration 950: error = 1.4285030, gradient norm = 0.0000761 (50 iterations in 7.736s)
# [t-SNE] Iteration 1000: error = 1.4202332, gradient norm = 0.0000709 (50 iterations in 7.640s)
# [t-SNE] Error after 1000 iterations: 1.420233
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.232s...
# [t-SNE] Computed neighbors for 7352 samples in 43.253s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.450s
# [t-SNE] Iteration 50: error = 85.6133575, gradient norm = 0.0277998 (50 iterations in 17.083s)
# [t-SNE] Iteration 100: error = 75.5704727, gradient norm = 0.0043104 (50 iterations in 14.382s)
# [t-SNE] Iteration 150: error = 74.6051865, gradient norm = 0.0024183 (50 iterations in 13.218s)
# [t-SNE] Iteration 200: error = 74.2391968, gradient norm = 0.0016678 (50 iterations in 12.816s)
# [t-SNE] Iteration 250: error = 74.0590210, gradient norm = 0.0012362 (50 iterations in 13.382s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.059021
# [t-SNE] Iteration 300: error = 2.1499283, gradient norm = 0.0011718 (50 iterations in 13.518s)
# [t-SNE] Iteration 350: error = 1.7548412, gradient norm = 0.0004813 (50 iterations in 13.000s)
# [t-SNE] Iteration 400: error = 1.5874330, gradient norm = 0.0002788 (50 iterations in 19.740s)
# [t-SNE] Iteration 450: error = 1.4935794, gradient norm = 0.0001892 (50 iterations in 25.386s)
# [t-SNE] Iteration 500: error = 1.4337561, gradient norm = 0.0001389 (50 iterations in 26.229s)
# [t-SNE] Iteration 550: error = 1.3927402, gradient norm = 0.0001100 (50 iterations in 19.045s)
# [t-SNE] Iteration 600: error = 1.3634335, gradient norm = 0.0000938 (50 iterations in 14.477s)
# [t-SNE] Iteration 650: error = 1.3422558, gradient norm = 0.0000851 (50 iterations in 13.621s)
# [t-SNE] Iteration 700: error = 1.3267893, gradient norm = 0.0000731 (50 iterations in 12.833s)
# [t-SNE] Iteration 750: error = 1.3147950, gradient norm = 0.0000661 (50 iterations in 12.706s)
# [t-SNE] Iteration 800: error = 1.3053808, gradient norm = 0.0000646 (50 iterations in 12.540s)
# [t-SNE] Iteration 850: error = 1.2981595, gradient norm = 0.0000600 (50 iterations in 12.690s)
# [t-SNE] Iteration 900: error = 1.2925295, gradient norm = 0.0000572 (50 iterations in 12.781s)
# [t-SNE] Iteration 950: error = 1.2878847, gradient norm = 0.0000544 (50 iterations in 12.949s)
# [t-SNE] Iteration 1000: error = 1.2838289, gradient norm = 0.0000523 (50 iterations in 13.159s)
# [t-SNE] Error after 1000 iterations: 1.283829
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # Conclusion:
# - All the classes have well defined clusters except for the 2 classes(SITTING and STANDING).
# - Even with different perplexity values, we observe that these 2 classes continnue to overlap.
# - The intuition seems logical, because in both these positions the Torso is upright and in rest.
# - Thus, one will face difficulties in separating the above 2 classes.
# - To get better classification, advice from domain experts can be taken.
